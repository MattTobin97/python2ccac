# %%
import pprint
music_library = {
    'AM':{
        'Artist': "Arctic Monkeys",
        'Tracks': {
            'Do I Wanna Know': 4.32,
            'R U Mine?': 3.22,
            'One For The Road': 3.26,
            'Arabella': 3.27,
            'I Want It All': 3.05,
            'No. 1 Party Anthem': 4.03,
            'Mad Sounds': 3.35,
            'Fireside': 3.01,
            'Whyd You Only Call Me When Youre High?': 2.41,
            'Snap Out Of It': 3.13,
            'Knee Socks': 4.18,
            'I Wanna Be Yours': 3.04,            
                  },
        'Release Year': 2013,
        'Genre': "Rock",
        'Rating': 7},
    
    'Better Strange':{
        'Artist': "James Supercave",
        'Tracks': {
            'Better Strange': 3.24,
            'Whatever You Want': 4.07,
            'Burn': 3.29,
            'Body Monsters': 3.54,
            'How to Start': 3.49,
            'Get Over Yourself': 3.37,
            'The Right Thing': 4.31,
            'Virtually a Girl': 4.41,
            'Chairman Gou': 4.02,
            'With You': 3.52,
            'Just Repeating Whats Around Me': 3.46,
            'Overloaded': 4.45},
        'Release Year': 2016,
        'Genre': "Rock",
        'Rating': 6},
    
    'Plastic Beach': {
        'Artist': "Gorillaz",
        'Tracks': {
            'Orchestral Intro (feat. sinfonia ViVA)': 1.09,
            'Welcome To The World of The Plastic Beach': 3.36,
            'White Flag': 3.43,
            'Rhinestone Eyes': 3.20,
            'Stylo': 4.31,
            'Superfast Jellyfish': 2.55,
            'Empire Ants': 4.44,
            'Glitter Freeze': 4.03,
            'Some Kind of Nature': 3.00,
            'On Melancholy Hill': 3.54,
            'Broken': 3.17,
            'Sweepstakes': 5.20,
            'Plastic Beach': 3.47,
            'To Binge': 3.56,
            'Cloud of Unknowing': 3.06,
            'Pirate Jet': 2.32},
        'Release Year': 2008,
        'Genre': "Alternative",
        'Rating': 6},
    
    'Belladonna of Sadness': {
        'Artist': "Alexandra Savior",
        'Tracks': {
            'Mirage': 3.26,
            'Bones': 2.49,
            'Shades': 3.50,
            'Girlie': 3.23,
            'Frankie': 3.48,
            'M.T.M.E.': 3.23,
            'Audeline': 3.50,
            'Cupid': 2.58,
            'Til Youre Mine': 3.33,
            'Vanishing Point': 4.20,
            'Mystery Girl': 5.35},
        'Release Year': 2017,
        'Genre': "Indie Rock",
        'Rating': 8},
    
    'Speaking In Tongues': {
        'Artist': "Talking Heads",
        'Tracks': {
            'Burning Down The House': 4.03,
            'Making Flippy Floppy': 5.55,
            'Girlfriend Is Better': 5.45,
            'Slippery People': 5.07,
            'I Get Wild/Wild Gravity': 5.17,
            'Swamp': 5.14,
            'Moon Rocks': 5.45,
            'Pull Up The Roots': 5.10,
            'This Must Be The Place(Naive Melody)': 4.55},
        'Release Year': 1983,
        'Genre': "Alternative Rock",
        'Rating': 7},
        
}


prompt = input('Which album would you like to look up? ')
if prompt in music_library:
    print (music_library[prompt])
else:
    print ("Try again")
# Out:
# Which album would you like to look up? AM
# {'Artist': 'Arctic Monkeys', 'Tracks': {'Do I Wanna Know': 4.32, 'R U Mine?': 3.22, 'One For The Road': 3.26, 'Arabella': 3.27, 'I Want It All': 3.05, 'No. 1 Party Anthem': 4.03, 'Mad Sounds': 3.35, 'Fireside': 3.01, 'Whyd You Only Call Me When Youre High?': 2.41, 'Snap Out Of It': 3.13, 'Knee Socks': 4.18, 'I Wanna Be Yours': 3.04}, 'Release Year': 2013, 'Genre': 'Rock', 'Rating': 7}
